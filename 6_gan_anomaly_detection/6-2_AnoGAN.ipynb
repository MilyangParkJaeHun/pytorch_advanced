# %% [markdown]
# # 6.2 AnoGAN

# %%
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Generator

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(z_dim, image_size * 8,
                               kernel_size=4, stride=1),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 8, image_size * 4,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 4, image_size * 2,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        self.layer4 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 2, image_size,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

input_z = torch.randn(1, 20)

input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

fake_images = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminator

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, image_size, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer2 = nn.Sequential(
            nn.Conv2d(image_size, image_size*2, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer4 = nn.Sequential(
            nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)

        feature = out 
        feature = feature.view(feature.size()[0], -1)

        out = self.last(out)

        return out, feature

# %%
D = Discriminator(z_dim=20, image_size=64)

input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)

d_out = D(fake_images)

print(nn.Sigmoid()(d_out[0]))

print(d_out[1].shape)
# Out:
# tensor([[[[0.5066]]]], grad_fn=<SigmoidBackward>)
# torch.Size([1, 8192])

# %% [markdown]
# # DataLoader

# %%
def make_datapath_list():

    train_img_list = list() 
    
    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, index):

        img_path = self.file_list[index]
        img = Image.open(img_path) 

        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoader

train_img_list=make_datapath_list()

# Dataset
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoader
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

batch_iterator = iter(train_dataloader) 
imges = next(batch_iterator)  
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


G.apply(weights_init)
D.apply(weights_init)
# Out:
# Discriminator(
#   (layer1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (layer4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (last): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1))
# )

# %%
def train_model(G, D, dataloader, num_epochs):

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    z_dim = 20
    mini_batch_size = 64

    G.to(device)
    D.to(device)

    G.train()  
    D.train() 

    torch.backends.cudnn.benchmark = True

    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    iteration = 1
    logs = []

    # epoch
    for epoch in range(num_epochs):

        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epoch
        epoch_d_loss = 0.0  # epoch

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        for imges in dataloader:

            # --------------------
            # 1. Discriminator
            # --------------------
            if imges.size()[0] == 1:
                continue

            imges = imges.to(device)

            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            d_out_real, _ = D(imges)

            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images)

            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generator
            # --------------------
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images)

            g_loss = criterion(d_out_fake.view(-1), label_real)

            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    return G, D

# %%
num_epochs = 300
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# -------------
# Epoch 0/300
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.0689 ||Epoch_G_Loss:0.2649
# timer:  1.7292 sec.
# -------------
# Epoch 1/300
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.5844
# timer:  0.2884 sec.
# -------------
# Epoch 2/300
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.2477 ||Epoch_G_Loss:0.6156
# timer:  0.2732 sec.
# -------------
# Epoch 3/300
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.0400 ||Epoch_G_Loss:0.2153
# timer:  0.2813 sec.
# -------------
# Epoch 4/300
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.0062 ||Epoch_G_Loss:0.4022
# timer:  0.2722 sec.
# -------------
# Epoch 5/300
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.2370 ||Epoch_G_Loss:0.4528
# timer:  0.2725 sec.
# -------------
# Epoch 6/300
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.0933 ||Epoch_G_Loss:0.1054
# timer:  0.2803 sec.
# -------------
# Epoch 7/300
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.0297 ||Epoch_G_Loss:0.2755
# timer:  0.2839 sec.
# -------------
# Epoch 8/300
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.1482 ||Epoch_G_Loss:0.1133
# timer:  0.2714 sec.
# -------------
# Epoch 9/300
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.0169 ||Epoch_G_Loss:0.2889
# timer:  0.2882 sec.
# -------------
# Epoch 10/300
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.0078 ||Epoch_G_Loss:0.4508
# timer:  0.2793 sec.
# -------------
# Epoch 11/300
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.3073 ||Epoch_G_Loss:0.0705
# timer:  0.2710 sec.
# -------------
# Epoch 12/300
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.0398 ||Epoch_G_Loss:0.2169
# timer:  0.2734 sec.
# -------------
# Epoch 13/300
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.0350 ||Epoch_G_Loss:0.3857
# timer:  0.2793 sec.
# -------------
# Epoch 14/300
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0100 ||Epoch_G_Loss:0.4182
# timer:  0.2792 sec.
# -------------
# Epoch 15/300
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0019 ||Epoch_G_Loss:0.5325
# timer:  0.2720 sec.
# -------------
# Epoch 16/300
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:0.5877
# timer:  0.2712 sec.
# -------------
# Epoch 17/300
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.3772 ||Epoch_G_Loss:0.9015
# timer:  0.2792 sec.
# -------------
# Epoch 18/300
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0434 ||Epoch_G_Loss:0.3460
# timer:  0.2785 sec.
# -------------
# Epoch 19/300
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0059 ||Epoch_G_Loss:0.4751
# timer:  0.2717 sec.
# -------------
# Epoch 20/300
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.0023 ||Epoch_G_Loss:0.5644
# timer:  0.2743 sec.
# -------------
# Epoch 21/300
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.2806 ||Epoch_G_Loss:0.5495
# timer:  0.2714 sec.
# -------------
# Epoch 22/300
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0389 ||Epoch_G_Loss:0.3176
# timer:  0.2720 sec.
# -------------
# Epoch 23/300
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.0146 ||Epoch_G_Loss:0.3711
# timer:  0.2750 sec.
# -------------
# Epoch 24/300
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.1391 ||Epoch_G_Loss:0.2974
# timer:  0.2735 sec.
# -------------
# Epoch 25/300
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.0127 ||Epoch_G_Loss:0.3781
# timer:  0.2722 sec.
# -------------
# Epoch 26/300
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.1978 ||Epoch_G_Loss:0.4477
# timer:  0.2748 sec.
# -------------
# Epoch 27/300
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.0265 ||Epoch_G_Loss:0.3001
# timer:  0.2852 sec.
# -------------
# Epoch 28/300
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.1409 ||Epoch_G_Loss:0.3318
# timer:  0.2704 sec.
# -------------
# Epoch 29/300
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.1049 ||Epoch_G_Loss:0.2535
# timer:  0.2724 sec.
# -------------
# Epoch 30/300
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.0395 ||Epoch_G_Loss:0.1887
# timer:  0.2793 sec.
# -------------
# Epoch 31/300
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.1100 ||Epoch_G_Loss:0.2430
# timer:  0.2730 sec.
# -------------
# Epoch 32/300
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.1122 ||Epoch_G_Loss:0.2155
# timer:  0.2793 sec.
# -------------
# Epoch 33/300
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.1043 ||Epoch_G_Loss:0.2214
# timer:  0.2714 sec.
# -------------
# Epoch 34/300
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.1083 ||Epoch_G_Loss:0.2248
# timer:  0.2728 sec.
# -------------
# Epoch 35/300
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.0843 ||Epoch_G_Loss:0.1507
# timer:  0.2724 sec.
# -------------
# Epoch 36/300
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.1062 ||Epoch_G_Loss:0.2212
# timer:  0.2724 sec.
# -------------
# Epoch 37/300
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.1407 ||Epoch_G_Loss:0.1613
# timer:  0.2726 sec.
# -------------
# Epoch 38/300
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.1040 ||Epoch_G_Loss:0.1565
# timer:  0.2795 sec.
# -------------
# Epoch 39/300
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.1193 ||Epoch_G_Loss:0.1612
# timer:  0.2768 sec.
# -------------
# Epoch 40/300
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.0993 ||Epoch_G_Loss:0.1464
# timer:  0.2758 sec.
# -------------
# Epoch 41/300
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.0969 ||Epoch_G_Loss:0.1708
# timer:  0.2712 sec.
# -------------
# Epoch 42/300
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.1117 ||Epoch_G_Loss:0.1642
# timer:  0.2785 sec.
# -------------
# Epoch 43/300
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.1054 ||Epoch_G_Loss:0.1376
# timer:  0.2733 sec.
# -------------
# Epoch 44/300
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.0911 ||Epoch_G_Loss:0.1575
# timer:  0.2714 sec.
# -------------
# Epoch 45/300
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.1573 ||Epoch_G_Loss:0.1710
# timer:  0.2761 sec.
# -------------
# Epoch 46/300
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.1163 ||Epoch_G_Loss:0.1451
# timer:  0.2839 sec.
# -------------
# Epoch 47/300
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.1163 ||Epoch_G_Loss:0.1903
# timer:  0.2706 sec.
# -------------
# Epoch 48/300
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.1184 ||Epoch_G_Loss:0.1339
# timer:  0.2742 sec.
# -------------
# Epoch 49/300
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.1295 ||Epoch_G_Loss:0.1088
# timer:  0.2790 sec.
# -------------
# Epoch 50/300
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.1331 ||Epoch_G_Loss:0.1499
# timer:  0.2768 sec.
# -------------
# Epoch 51/300
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.1176 ||Epoch_G_Loss:0.1069
# timer:  0.2732 sec.
# -------------
# Epoch 52/300
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.1207 ||Epoch_G_Loss:0.1417
# timer:  0.2718 sec.
# -------------
# Epoch 53/300
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.1491 ||Epoch_G_Loss:0.1214
# timer:  0.2729 sec.
# -------------
# Epoch 54/300
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.1133 ||Epoch_G_Loss:0.1347
# timer:  0.2724 sec.
# -------------
# Epoch 55/300
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.1353 ||Epoch_G_Loss:0.1203
# timer:  0.2721 sec.
# -------------
# Epoch 56/300
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.1334 ||Epoch_G_Loss:0.1017
# timer:  0.2728 sec.
# -------------
# Epoch 57/300
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.1372 ||Epoch_G_Loss:0.1157
# timer:  0.2731 sec.
# -------------
# Epoch 58/300
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.1188 ||Epoch_G_Loss:0.1127
# timer:  0.2741 sec.
# -------------
# Epoch 59/300
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.1378 ||Epoch_G_Loss:0.1161
# timer:  0.2717 sec.
# -------------
# Epoch 60/300
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.1213 ||Epoch_G_Loss:0.1253
# timer:  0.2742 sec.
# -------------
# Epoch 61/300
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.1263 ||Epoch_G_Loss:0.1208
# timer:  0.2788 sec.
# -------------
# Epoch 62/300
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.1148 ||Epoch_G_Loss:0.1267
# timer:  0.2720 sec.
# -------------
# Epoch 63/300
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.1161 ||Epoch_G_Loss:0.1288
# timer:  0.2772 sec.
# -------------
# Epoch 64/300
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.1190 ||Epoch_G_Loss:0.1286
# timer:  0.2729 sec.
# -------------
# Epoch 65/300
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.1263 ||Epoch_G_Loss:0.1118
# timer:  0.2740 sec.
# -------------
# Epoch 66/300
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.1161 ||Epoch_G_Loss:0.1447
# timer:  0.2709 sec.
# -------------
# Epoch 67/300
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.1023 ||Epoch_G_Loss:0.1370
# timer:  0.2737 sec.
# -------------
# Epoch 68/300
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.1206 ||Epoch_G_Loss:0.1167
# timer:  0.2723 sec.
# -------------
# Epoch 69/300
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.1156 ||Epoch_G_Loss:0.1485
# timer:  0.2797 sec.
# -------------
# Epoch 70/300
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0860 ||Epoch_G_Loss:0.1618
# timer:  0.2716 sec.
# -------------
# Epoch 71/300
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.1548 ||Epoch_G_Loss:0.1289
# timer:  0.2727 sec.
# -------------
# Epoch 72/300
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0806 ||Epoch_G_Loss:0.1500
# timer:  0.2794 sec.
# -------------
# Epoch 73/300
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.1187 ||Epoch_G_Loss:0.1728
# timer:  0.2721 sec.
# -------------
# Epoch 74/300
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.1029 ||Epoch_G_Loss:0.1554
# timer:  0.2741 sec.
# -------------
# Epoch 75/300
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0922 ||Epoch_G_Loss:0.1623
# timer:  0.2709 sec.
# -------------
# Epoch 76/300
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.1171 ||Epoch_G_Loss:0.1577
# timer:  0.2738 sec.
# -------------
# Epoch 77/300
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0820 ||Epoch_G_Loss:0.1448
# timer:  0.2719 sec.
# -------------
# Epoch 78/300
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.1111 ||Epoch_G_Loss:0.1596
# timer:  0.2743 sec.
# -------------
# Epoch 79/300
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.1122 ||Epoch_G_Loss:0.1551
# timer:  0.2735 sec.
# -------------
# Epoch 80/300
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0965 ||Epoch_G_Loss:0.1652
# timer:  0.2729 sec.
# -------------
# Epoch 81/300
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.0865 ||Epoch_G_Loss:0.1544
# timer:  0.2727 sec.
# -------------
# Epoch 82/300
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.1159 ||Epoch_G_Loss:0.1821
# timer:  0.2721 sec.
# -------------
# Epoch 83/300
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.1040 ||Epoch_G_Loss:0.1696
# timer:  0.2785 sec.
# -------------
# Epoch 84/300
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0847 ||Epoch_G_Loss:0.1527
# timer:  0.2748 sec.
# -------------
# Epoch 85/300
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.1040 ||Epoch_G_Loss:0.1752
# timer:  0.2728 sec.
# -------------
# Epoch 86/300
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1468
# timer:  0.2745 sec.
# -------------
# Epoch 87/300
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.1159 ||Epoch_G_Loss:0.1703
# timer:  0.2730 sec.
# -------------
# Epoch 88/300
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.0917 ||Epoch_G_Loss:0.1625
# timer:  0.2749 sec.
# -------------
# Epoch 89/300
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0854 ||Epoch_G_Loss:0.1802
# timer:  0.2740 sec.
# -------------
# Epoch 90/300
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.1027 ||Epoch_G_Loss:0.1381
# timer:  0.2735 sec.
# -------------
# Epoch 91/300
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.1166 ||Epoch_G_Loss:0.1748
# timer:  0.2717 sec.
# -------------
# Epoch 92/300
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0771 ||Epoch_G_Loss:0.1561
# timer:  0.2893 sec.
# -------------
# Epoch 93/300
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.1144 ||Epoch_G_Loss:0.1630
# timer:  0.2816 sec.
# -------------
# Epoch 94/300
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0986 ||Epoch_G_Loss:0.1681
# timer:  0.2744 sec.
# -------------
# Epoch 95/300
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0964 ||Epoch_G_Loss:0.1749
# timer:  0.2848 sec.
# -------------
# Epoch 96/300
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0820 ||Epoch_G_Loss:0.1718
# timer:  0.2726 sec.
# -------------
# Epoch 97/300
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0969 ||Epoch_G_Loss:0.1617
# timer:  0.2743 sec.
# -------------
# Epoch 98/300
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0942 ||Epoch_G_Loss:0.1818
# timer:  0.2737 sec.
# -------------
# Epoch 99/300
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0942 ||Epoch_G_Loss:0.1782
# timer:  0.2901 sec.
# -------------
# Epoch 100/300
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0797 ||Epoch_G_Loss:0.1803
# timer:  0.2813 sec.
# -------------
# Epoch 101/300
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0957 ||Epoch_G_Loss:0.1531
# timer:  0.2719 sec.
# -------------
# Epoch 102/300
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0850 ||Epoch_G_Loss:0.1871
# timer:  0.2885 sec.
# -------------
# Epoch 103/300
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0903 ||Epoch_G_Loss:0.1649
# timer:  0.2776 sec.
# -------------
# Epoch 104/300
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0644 ||Epoch_G_Loss:0.1910
# timer:  0.2734 sec.
# -------------
# Epoch 105/300
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.1296 ||Epoch_G_Loss:0.1907
# timer:  0.2717 sec.
# -------------
# Epoch 106/300
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0870 ||Epoch_G_Loss:0.1824
# timer:  0.2745 sec.
# -------------
# Epoch 107/300
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0792 ||Epoch_G_Loss:0.1826
# timer:  0.2718 sec.
# -------------
# Epoch 108/300
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0974 ||Epoch_G_Loss:0.1868
# timer:  0.2719 sec.
# -------------
# Epoch 109/300
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0871 ||Epoch_G_Loss:0.1875
# timer:  0.2851 sec.
# -------------
# Epoch 110/300
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0827 ||Epoch_G_Loss:0.1848
# timer:  0.2799 sec.
# -------------
# Epoch 111/300
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0890 ||Epoch_G_Loss:0.2040
# timer:  0.2915 sec.
# -------------
# Epoch 112/300
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0897 ||Epoch_G_Loss:0.1763
# timer:  0.2786 sec.
# -------------
# Epoch 113/300
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0833 ||Epoch_G_Loss:0.1941
# timer:  0.2902 sec.
# -------------
# Epoch 114/300
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0902 ||Epoch_G_Loss:0.1802
# timer:  0.2795 sec.
# -------------
# Epoch 115/300
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0794 ||Epoch_G_Loss:0.1989
# timer:  0.2773 sec.
# -------------
# Epoch 116/300
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0859 ||Epoch_G_Loss:0.1704
# timer:  0.2746 sec.
# -------------
# Epoch 117/300
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0847 ||Epoch_G_Loss:0.2001
# timer:  0.2721 sec.
# -------------
# Epoch 118/300
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0931 ||Epoch_G_Loss:0.1847
# timer:  0.2760 sec.
# -------------
# Epoch 119/300
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0858 ||Epoch_G_Loss:0.1903
# timer:  0.2790 sec.
# -------------
# Epoch 120/300
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0794 ||Epoch_G_Loss:0.1957
# timer:  0.2943 sec.
# -------------
# Epoch 121/300
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0766 ||Epoch_G_Loss:0.2058
# timer:  0.2802 sec.
# -------------
# Epoch 122/300
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0788 ||Epoch_G_Loss:0.1804
# timer:  0.2798 sec.
# -------------
# Epoch 123/300
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0786 ||Epoch_G_Loss:0.2026
# timer:  0.2790 sec.
# -------------
# Epoch 124/300
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0972 ||Epoch_G_Loss:0.2113
# timer:  0.2816 sec.
# -------------
# Epoch 125/300
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.0607 ||Epoch_G_Loss:0.2072
# timer:  0.2736 sec.
# -------------
# Epoch 126/300
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0908 ||Epoch_G_Loss:0.2172
# timer:  0.2847 sec.
# -------------
# Epoch 127/300
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0568 ||Epoch_G_Loss:0.2146
# timer:  0.2744 sec.
# -------------
# Epoch 128/300
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0863 ||Epoch_G_Loss:0.2478
# timer:  0.2734 sec.
# -------------
# Epoch 129/300
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0756 ||Epoch_G_Loss:0.1956
# timer:  0.2828 sec.
# -------------
# Epoch 130/300
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0639 ||Epoch_G_Loss:0.2190
# timer:  0.2748 sec.
# -------------
# Epoch 131/300
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0800 ||Epoch_G_Loss:0.2103
# timer:  0.2792 sec.
# -------------
# Epoch 132/300
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0692 ||Epoch_G_Loss:0.2436
# timer:  0.2778 sec.
# -------------
# Epoch 133/300
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0681 ||Epoch_G_Loss:0.2051
# timer:  0.2791 sec.
# -------------
# Epoch 134/300
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0778 ||Epoch_G_Loss:0.2452
# timer:  0.2720 sec.
# -------------
# Epoch 135/300
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0652 ||Epoch_G_Loss:0.2201
# timer:  0.2740 sec.
# -------------
# Epoch 136/300
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0821 ||Epoch_G_Loss:0.2507
# timer:  0.2730 sec.
# -------------
# Epoch 137/300
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0605 ||Epoch_G_Loss:0.2162
# timer:  0.2747 sec.
# -------------
# Epoch 138/300
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0686 ||Epoch_G_Loss:0.2338
# timer:  0.2732 sec.
# -------------
# Epoch 139/300
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0555 ||Epoch_G_Loss:0.2372
# timer:  0.2743 sec.
# -------------
# Epoch 140/300
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0862 ||Epoch_G_Loss:0.2254
# timer:  0.2728 sec.
# -------------
# Epoch 141/300
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0495 ||Epoch_G_Loss:0.2423
# timer:  0.2889 sec.
# -------------
# Epoch 142/300
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0789 ||Epoch_G_Loss:0.2367
# timer:  0.2791 sec.
# -------------
# Epoch 143/300
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0614 ||Epoch_G_Loss:0.2461
# timer:  0.2748 sec.
# -------------
# Epoch 144/300
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0513 ||Epoch_G_Loss:0.2631
# timer:  0.2827 sec.
# -------------
# Epoch 145/300
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0894 ||Epoch_G_Loss:0.1988
# timer:  0.2860 sec.
# -------------
# Epoch 146/300
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0602 ||Epoch_G_Loss:0.2567
# timer:  0.2723 sec.
# -------------
# Epoch 147/300
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0592 ||Epoch_G_Loss:0.2550
# timer:  0.2738 sec.
# -------------
# Epoch 148/300
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0661 ||Epoch_G_Loss:0.2602
# timer:  0.2724 sec.
# -------------
# Epoch 149/300
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0566 ||Epoch_G_Loss:0.2553
# timer:  0.2738 sec.
# -------------
# Epoch 150/300
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0656 ||Epoch_G_Loss:0.2561
# timer:  0.2801 sec.
# -------------
# Epoch 151/300
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0531 ||Epoch_G_Loss:0.2487
# timer:  0.2741 sec.
# -------------
# Epoch 152/300
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0741 ||Epoch_G_Loss:0.2478
# timer:  0.2747 sec.
# -------------
# Epoch 153/300
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0363 ||Epoch_G_Loss:0.2662
# timer:  0.2863 sec.
# -------------
# Epoch 154/300
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0751 ||Epoch_G_Loss:0.2766
# timer:  0.2790 sec.
# -------------
# Epoch 155/300
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0493 ||Epoch_G_Loss:0.2564
# timer:  0.2807 sec.
# -------------
# Epoch 156/300
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0690 ||Epoch_G_Loss:0.2706
# timer:  0.2862 sec.
# -------------
# Epoch 157/300
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0304 ||Epoch_G_Loss:0.3235
# timer:  0.2722 sec.
# -------------
# Epoch 158/300
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.1178 ||Epoch_G_Loss:0.2560
# timer:  0.2743 sec.
# -------------
# Epoch 159/300
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0421 ||Epoch_G_Loss:0.2865
# timer:  0.2729 sec.
# -------------
# Epoch 160/300
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0559 ||Epoch_G_Loss:0.2737
# timer:  0.2740 sec.
# -------------
# Epoch 161/300
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0639 ||Epoch_G_Loss:0.3240
# timer:  0.2721 sec.
# -------------
# Epoch 162/300
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0498 ||Epoch_G_Loss:0.2755
# timer:  0.2742 sec.
# -------------
# Epoch 163/300
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0679 ||Epoch_G_Loss:0.2780
# timer:  0.2725 sec.
# -------------
# Epoch 164/300
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.0356 ||Epoch_G_Loss:0.2989
# timer:  0.2797 sec.
# -------------
# Epoch 165/300
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.0725 ||Epoch_G_Loss:0.2856
# timer:  0.2743 sec.
# -------------
# Epoch 166/300
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0446 ||Epoch_G_Loss:0.3336
# timer:  0.2747 sec.
# -------------
# Epoch 167/300
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.0521 ||Epoch_G_Loss:0.2371
# timer:  0.2742 sec.
# -------------
# Epoch 168/300
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.0752 ||Epoch_G_Loss:0.2959
# timer:  0.2726 sec.
# -------------
# Epoch 169/300
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0406 ||Epoch_G_Loss:0.2954
# timer:  0.2746 sec.
# -------------
# Epoch 170/300
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.0478 ||Epoch_G_Loss:0.3196
# timer:  0.2800 sec.
# -------------
# Epoch 171/300
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0566 ||Epoch_G_Loss:0.2809
# timer:  0.2744 sec.
# -------------
# Epoch 172/300
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.0486 ||Epoch_G_Loss:0.3056
# timer:  0.2742 sec.
# -------------
# Epoch 173/300
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.0590 ||Epoch_G_Loss:0.3208
# timer:  0.2897 sec.
# -------------
# Epoch 174/300
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0359 ||Epoch_G_Loss:0.2931
# timer:  0.2745 sec.
# -------------
# Epoch 175/300
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0701 ||Epoch_G_Loss:0.3089
# timer:  0.2739 sec.
# -------------
# Epoch 176/300
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0396 ||Epoch_G_Loss:0.2932
# timer:  0.2748 sec.
# -------------
# Epoch 177/300
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0536 ||Epoch_G_Loss:0.2938
# timer:  0.2728 sec.
# -------------
# Epoch 178/300
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0581 ||Epoch_G_Loss:0.3340
# timer:  0.2740 sec.
# -------------
# Epoch 179/300
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0401 ||Epoch_G_Loss:0.3072
# timer:  0.2885 sec.
# -------------
# Epoch 180/300
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0518 ||Epoch_G_Loss:0.3102
# timer:  0.2743 sec.
# -------------
# Epoch 181/300
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0289 ||Epoch_G_Loss:0.3492
# timer:  0.2746 sec.
# -------------
# Epoch 182/300
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0570 ||Epoch_G_Loss:0.3039
# timer:  0.2739 sec.
# -------------
# Epoch 183/300
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0424 ||Epoch_G_Loss:0.3551
# timer:  0.2757 sec.
# -------------
# Epoch 184/300
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.0668 ||Epoch_G_Loss:0.3066
# timer:  0.2798 sec.
# -------------
# Epoch 185/300
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.0315 ||Epoch_G_Loss:0.3228
# timer:  0.2732 sec.
# -------------
# Epoch 186/300
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0462 ||Epoch_G_Loss:0.3413
# timer:  0.2747 sec.
# -------------
# Epoch 187/300
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.0277 ||Epoch_G_Loss:0.3567
# timer:  0.2773 sec.
# -------------
# Epoch 188/300
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0456 ||Epoch_G_Loss:0.3572
# timer:  0.2749 sec.
# -------------
# Epoch 189/300
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0609 ||Epoch_G_Loss:0.2968
# timer:  0.2780 sec.
# -------------
# Epoch 190/300
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0404 ||Epoch_G_Loss:0.3725
# timer:  0.2851 sec.
# -------------
# Epoch 191/300
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0419 ||Epoch_G_Loss:0.3543
# timer:  0.2750 sec.
# -------------
# Epoch 192/300
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0317 ||Epoch_G_Loss:0.3842
# timer:  0.2749 sec.
# -------------
# Epoch 193/300
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0399 ||Epoch_G_Loss:0.3347
# timer:  0.2758 sec.
# -------------
# Epoch 194/300
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.0357 ||Epoch_G_Loss:0.4040
# timer:  0.2805 sec.
# -------------
# Epoch 195/300
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.0383 ||Epoch_G_Loss:0.3538
# timer:  0.2746 sec.
# -------------
# Epoch 196/300
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.0306 ||Epoch_G_Loss:0.4130
# timer:  0.2753 sec.
# -------------
# Epoch 197/300
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.0577 ||Epoch_G_Loss:0.2812
# timer:  0.2749 sec.
# -------------
# Epoch 198/300
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.0519 ||Epoch_G_Loss:0.4180
# timer:  0.2830 sec.
# -------------
# Epoch 199/300
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.0272 ||Epoch_G_Loss:0.3829
# timer:  0.2847 sec.
# -------------
# Epoch 200/300
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.0558 ||Epoch_G_Loss:0.3985
# timer:  0.2814 sec.
# -------------
# Epoch 201/300
# -------------
# （train）
# -------------
# epoch 201 || Epoch_D_Loss:0.0338 ||Epoch_G_Loss:0.3230
# timer:  0.2913 sec.
# -------------
# Epoch 202/300
# -------------
# （train）
# -------------
# epoch 202 || Epoch_D_Loss:0.0358 ||Epoch_G_Loss:0.3629
# timer:  0.2752 sec.
# -------------
# Epoch 203/300
# -------------
# （train）
# -------------
# epoch 203 || Epoch_D_Loss:0.0110 ||Epoch_G_Loss:0.4232
# timer:  0.2760 sec.
# -------------
# Epoch 204/300
# -------------
# （train）
# -------------
# epoch 204 || Epoch_D_Loss:0.0814 ||Epoch_G_Loss:0.3546
# timer:  0.2744 sec.
# -------------
# Epoch 205/300
# -------------
# （train）
# -------------
# epoch 205 || Epoch_D_Loss:0.0284 ||Epoch_G_Loss:0.3493
# timer:  0.2749 sec.
# -------------
# Epoch 206/300
# -------------
# （train）
# -------------
# epoch 206 || Epoch_D_Loss:0.0266 ||Epoch_G_Loss:0.4188
# timer:  0.2820 sec.
# -------------
# Epoch 207/300
# -------------
# （train）
# -------------
# epoch 207 || Epoch_D_Loss:0.0554 ||Epoch_G_Loss:0.3437
# timer:  0.2760 sec.
# -------------
# Epoch 208/300
# -------------
# （train）
# -------------
# epoch 208 || Epoch_D_Loss:0.0125 ||Epoch_G_Loss:0.4520
# timer:  0.2874 sec.
# -------------
# Epoch 209/300
# -------------
# （train）
# -------------
# epoch 209 || Epoch_D_Loss:0.0768 ||Epoch_G_Loss:0.3327
# timer:  0.2745 sec.
# -------------
# Epoch 210/300
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.0240 ||Epoch_G_Loss:0.3311
# timer:  0.2752 sec.
# -------------
# Epoch 211/300
# -------------
# （train）
# -------------
# epoch 211 || Epoch_D_Loss:0.0601 ||Epoch_G_Loss:0.4046
# timer:  0.2838 sec.
# -------------
# Epoch 212/300
# -------------
# （train）
# -------------
# epoch 212 || Epoch_D_Loss:0.0242 ||Epoch_G_Loss:0.3634
# timer:  0.2918 sec.
# -------------
# Epoch 213/300
# -------------
# （train）
# -------------
# epoch 213 || Epoch_D_Loss:0.0239 ||Epoch_G_Loss:0.4349
# timer:  0.2869 sec.
# -------------
# Epoch 214/300
# -------------
# （train）
# -------------
# epoch 214 || Epoch_D_Loss:0.0404 ||Epoch_G_Loss:0.3939
# timer:  0.2740 sec.
# -------------
# Epoch 215/300
# -------------
# （train）
# -------------
# epoch 215 || Epoch_D_Loss:0.0224 ||Epoch_G_Loss:0.4267
# timer:  0.2758 sec.
# -------------
# Epoch 216/300
# -------------
# （train）
# -------------
# epoch 216 || Epoch_D_Loss:0.0134 ||Epoch_G_Loss:0.4560
# timer:  0.2745 sec.
# -------------
# Epoch 217/300
# -------------
# （train）
# -------------
# epoch 217 || Epoch_D_Loss:0.0562 ||Epoch_G_Loss:0.3601
# timer:  0.2751 sec.
# -------------
# Epoch 218/300
# -------------
# （train）
# -------------
# epoch 218 || Epoch_D_Loss:0.0369 ||Epoch_G_Loss:0.4631
# timer:  0.2731 sec.
# -------------
# Epoch 219/300
# -------------
# （train）
# -------------
# epoch 219 || Epoch_D_Loss:0.0235 ||Epoch_G_Loss:0.3976
# timer:  0.2748 sec.
# -------------
# Epoch 220/300
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.0488 ||Epoch_G_Loss:0.3857
# timer:  0.2818 sec.
# -------------
# Epoch 221/300
# -------------
# （train）
# -------------
# epoch 221 || Epoch_D_Loss:0.0210 ||Epoch_G_Loss:0.4197
# timer:  0.2811 sec.
# -------------
# Epoch 222/300
# -------------
# （train）
# -------------
# epoch 222 || Epoch_D_Loss:0.0335 ||Epoch_G_Loss:0.4167
# timer:  0.2740 sec.
# -------------
# Epoch 223/300
# -------------
# （train）
# -------------
# epoch 223 || Epoch_D_Loss:0.0298 ||Epoch_G_Loss:0.4612
# timer:  0.2752 sec.
# -------------
# Epoch 224/300
# -------------
# （train）
# -------------
# epoch 224 || Epoch_D_Loss:0.0327 ||Epoch_G_Loss:0.3863
# timer:  0.2756 sec.
# -------------
# Epoch 225/300
# -------------
# （train）
# -------------
# epoch 225 || Epoch_D_Loss:0.0230 ||Epoch_G_Loss:0.4590
# timer:  0.2758 sec.
# -------------
# Epoch 226/300
# -------------
# （train）
# -------------
# epoch 226 || Epoch_D_Loss:0.0371 ||Epoch_G_Loss:0.4816
# timer:  0.2786 sec.
# -------------
# Epoch 227/300
# -------------
# （train）
# -------------
# epoch 227 || Epoch_D_Loss:0.0414 ||Epoch_G_Loss:0.3452
# timer:  0.2747 sec.
# -------------
# Epoch 228/300
# -------------
# （train）
# -------------
# epoch 228 || Epoch_D_Loss:0.0098 ||Epoch_G_Loss:0.4893
# timer:  0.2787 sec.
# -------------
# Epoch 229/300
# -------------
# （train）
# -------------
# epoch 229 || Epoch_D_Loss:0.0619 ||Epoch_G_Loss:0.4122
# timer:  0.2782 sec.
# -------------
# Epoch 230/300
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.0113 ||Epoch_G_Loss:0.4600
# timer:  0.2782 sec.
# -------------
# Epoch 231/300
# -------------
# （train）
# -------------
# epoch 231 || Epoch_D_Loss:0.0273 ||Epoch_G_Loss:0.4596
# timer:  0.2749 sec.
# -------------
# Epoch 232/300
# -------------
# （train）
# -------------
# epoch 232 || Epoch_D_Loss:0.0239 ||Epoch_G_Loss:0.4834
# timer:  0.2760 sec.
# -------------
# Epoch 233/300
# -------------
# （train）
# -------------
# epoch 233 || Epoch_D_Loss:0.0299 ||Epoch_G_Loss:0.4373
# timer:  0.2741 sec.
# -------------
# Epoch 234/300
# -------------
# （train）
# -------------
# epoch 234 || Epoch_D_Loss:0.0305 ||Epoch_G_Loss:0.5135
# timer:  0.2748 sec.
# -------------
# Epoch 235/300
# -------------
# （train）
# -------------
# epoch 235 || Epoch_D_Loss:0.0354 ||Epoch_G_Loss:0.4054
# timer:  0.2748 sec.
# -------------
# Epoch 236/300
# -------------
# （train）
# -------------
# epoch 236 || Epoch_D_Loss:0.0206 ||Epoch_G_Loss:0.5095
# timer:  0.2867 sec.
# -------------
# Epoch 237/300
# -------------
# （train）
# -------------
# epoch 237 || Epoch_D_Loss:0.0202 ||Epoch_G_Loss:0.4443
# timer:  0.2745 sec.
# -------------
# Epoch 238/300
# -------------
# （train）
# -------------
# epoch 238 || Epoch_D_Loss:0.0369 ||Epoch_G_Loss:0.5327
# timer:  0.2752 sec.
# -------------
# Epoch 239/300
# -------------
# （train）
# -------------
# epoch 239 || Epoch_D_Loss:0.0412 ||Epoch_G_Loss:0.3912
# timer:  0.2750 sec.
# -------------
# Epoch 240/300
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.0114 ||Epoch_G_Loss:0.5180
# timer:  0.2758 sec.
# -------------
# Epoch 241/300
# -------------
# （train）
# -------------
# epoch 241 || Epoch_D_Loss:0.0497 ||Epoch_G_Loss:0.4902
# timer:  0.2732 sec.
# -------------
# Epoch 242/300
# -------------
# （train）
# -------------
# epoch 242 || Epoch_D_Loss:0.0088 ||Epoch_G_Loss:0.5285
# timer:  0.2748 sec.
# -------------
# Epoch 243/300
# -------------
# （train）
# -------------
# epoch 243 || Epoch_D_Loss:0.0057 ||Epoch_G_Loss:0.5884
# timer:  0.2735 sec.
# -------------
# Epoch 244/300
# -------------
# （train）
# -------------
# epoch 244 || Epoch_D_Loss:0.0776 ||Epoch_G_Loss:0.4354
# timer:  0.2751 sec.
# -------------
# Epoch 245/300
# -------------
# （train）
# -------------
# epoch 245 || Epoch_D_Loss:0.0114 ||Epoch_G_Loss:0.4836
# timer:  0.2753 sec.
# -------------
# Epoch 246/300
# -------------
# （train）
# -------------
# epoch 246 || Epoch_D_Loss:0.0163 ||Epoch_G_Loss:0.5338
# timer:  0.2756 sec.
# -------------
# Epoch 247/300
# -------------
# （train）
# -------------
# epoch 247 || Epoch_D_Loss:0.0460 ||Epoch_G_Loss:0.4643
# timer:  0.2758 sec.
# -------------
# Epoch 248/300
# -------------
# （train）
# -------------
# epoch 248 || Epoch_D_Loss:0.0183 ||Epoch_G_Loss:0.4276
# timer:  0.2744 sec.
# -------------
# Epoch 249/300
# -------------
# （train）
# -------------
# epoch 249 || Epoch_D_Loss:0.0109 ||Epoch_G_Loss:0.6337
# timer:  0.2750 sec.
# -------------
# Epoch 250/300
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.0465 ||Epoch_G_Loss:0.4136
# timer:  0.2801 sec.
# -------------
# Epoch 251/300
# -------------
# （train）
# -------------
# epoch 251 || Epoch_D_Loss:0.0094 ||Epoch_G_Loss:0.5264
# timer:  0.2816 sec.
# -------------
# Epoch 252/300
# -------------
# （train）
# -------------
# epoch 252 || Epoch_D_Loss:0.0060 ||Epoch_G_Loss:0.5780
# timer:  0.2744 sec.
# -------------
# Epoch 253/300
# -------------
# （train）
# -------------
# epoch 253 || Epoch_D_Loss:0.0681 ||Epoch_G_Loss:0.4163
# timer:  0.2750 sec.
# -------------
# Epoch 254/300
# -------------
# （train）
# -------------
# epoch 254 || Epoch_D_Loss:0.0074 ||Epoch_G_Loss:0.5329
# timer:  0.2749 sec.
# -------------
# Epoch 255/300
# -------------
# （train）
# -------------
# epoch 255 || Epoch_D_Loss:0.0177 ||Epoch_G_Loss:0.5540
# timer:  0.2753 sec.
# -------------
# Epoch 256/300
# -------------
# （train）
# -------------
# epoch 256 || Epoch_D_Loss:0.0457 ||Epoch_G_Loss:0.3964
# timer:  0.2808 sec.
# -------------
# Epoch 257/300
# -------------
# （train）
# -------------
# epoch 257 || Epoch_D_Loss:0.0055 ||Epoch_G_Loss:0.5800
# timer:  0.2732 sec.
# -------------
# Epoch 258/300
# -------------
# （train）
# -------------
# epoch 258 || Epoch_D_Loss:0.0309 ||Epoch_G_Loss:0.5556
# timer:  0.2756 sec.
# -------------
# Epoch 259/300
# -------------
# （train）
# -------------
# epoch 259 || Epoch_D_Loss:0.0199 ||Epoch_G_Loss:0.5170
# timer:  0.2744 sec.
# -------------
# Epoch 260/300
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.0325 ||Epoch_G_Loss:0.4961
# timer:  0.2750 sec.
# -------------
# Epoch 261/300
# -------------
# （train）
# -------------
# epoch 261 || Epoch_D_Loss:0.0073 ||Epoch_G_Loss:0.5870
# timer:  0.2753 sec.
# -------------
# Epoch 262/300
# -------------
# （train）
# -------------
# epoch 262 || Epoch_D_Loss:0.0220 ||Epoch_G_Loss:0.5545
# timer:  0.2748 sec.
# -------------
# Epoch 263/300
# -------------
# （train）
# -------------
# epoch 263 || Epoch_D_Loss:0.0250 ||Epoch_G_Loss:0.4750
# timer:  0.2748 sec.
# -------------
# Epoch 264/300
# -------------
# （train）
# -------------
# epoch 264 || Epoch_D_Loss:0.0040 ||Epoch_G_Loss:0.5980
# timer:  0.2742 sec.
# -------------
# Epoch 265/300
# -------------
# （train）
# -------------
# epoch 265 || Epoch_D_Loss:0.0462 ||Epoch_G_Loss:0.5202
# timer:  0.2762 sec.
# -------------
# Epoch 266/300
# -------------
# （train）
# -------------
# epoch 266 || Epoch_D_Loss:0.0100 ||Epoch_G_Loss:0.5483
# timer:  0.2740 sec.
# -------------
# Epoch 267/300
# -------------
# （train）
# -------------
# epoch 267 || Epoch_D_Loss:0.0308 ||Epoch_G_Loss:0.5029
# timer:  0.2753 sec.
# -------------
# Epoch 268/300
# -------------
# （train）
# -------------
# epoch 268 || Epoch_D_Loss:0.0042 ||Epoch_G_Loss:0.6283
# timer:  0.2753 sec.
# -------------
# Epoch 269/300
# -------------
# （train）
# -------------
# epoch 269 || Epoch_D_Loss:0.0553 ||Epoch_G_Loss:0.6002
# timer:  0.2754 sec.
# -------------
# Epoch 270/300
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.0304 ||Epoch_G_Loss:0.4400
# timer:  0.2751 sec.
# -------------
# Epoch 271/300
# -------------
# （train）
# -------------
# epoch 271 || Epoch_D_Loss:0.0151 ||Epoch_G_Loss:0.4989
# timer:  0.2744 sec.
# -------------
# Epoch 272/300
# -------------
# （train）
# -------------
# epoch 272 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.6471
# timer:  0.2765 sec.
# -------------
# Epoch 273/300
# -------------
# （train）
# -------------
# epoch 273 || Epoch_D_Loss:0.0345 ||Epoch_G_Loss:0.4348
# timer:  0.2743 sec.
# -------------
# Epoch 274/300
# -------------
# （train）
# -------------
# epoch 274 || Epoch_D_Loss:0.0044 ||Epoch_G_Loss:0.6263
# timer:  0.2751 sec.
# -------------
# Epoch 275/300
# -------------
# （train）
# -------------
# epoch 275 || Epoch_D_Loss:0.0346 ||Epoch_G_Loss:0.5185
# timer:  0.2817 sec.
# -------------
# Epoch 276/300
# -------------
# （train）
# -------------
# epoch 276 || Epoch_D_Loss:0.0119 ||Epoch_G_Loss:0.5395
# timer:  0.2797 sec.
# -------------
# Epoch 277/300
# -------------
# （train）
# -------------
# epoch 277 || Epoch_D_Loss:0.0445 ||Epoch_G_Loss:0.4912
# timer:  0.2743 sec.
# -------------
# Epoch 278/300
# -------------
# （train）
# -------------
# epoch 278 || Epoch_D_Loss:0.0056 ||Epoch_G_Loss:0.6119
# timer:  0.2766 sec.
# -------------
# Epoch 279/300
# -------------
# （train）
# -------------
# epoch 279 || Epoch_D_Loss:0.0380 ||Epoch_G_Loss:0.5520
# timer:  0.2748 sec.
# -------------
# Epoch 280/300
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.0102 ||Epoch_G_Loss:0.6089
# timer:  0.2760 sec.
# -------------
# Epoch 281/300
# -------------
# （train）
# -------------
# epoch 281 || Epoch_D_Loss:0.0127 ||Epoch_G_Loss:0.6217
# timer:  0.2761 sec.
# -------------
# Epoch 282/300
# -------------
# （train）
# -------------
# epoch 282 || Epoch_D_Loss:0.0348 ||Epoch_G_Loss:0.5116
# timer:  0.2750 sec.
# -------------
# Epoch 283/300
# -------------
# （train）
# -------------
# epoch 283 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.6255
# timer:  0.2764 sec.
# -------------
# Epoch 284/300
# -------------
# （train）
# -------------
# epoch 284 || Epoch_D_Loss:0.0123 ||Epoch_G_Loss:0.6906
# timer:  0.2766 sec.
# -------------
# Epoch 285/300
# -------------
# （train）
# -------------
# epoch 285 || Epoch_D_Loss:0.0500 ||Epoch_G_Loss:0.3938
# timer:  0.2786 sec.
# -------------
# Epoch 286/300
# -------------
# （train）
# -------------
# epoch 286 || Epoch_D_Loss:0.0063 ||Epoch_G_Loss:0.6209
# timer:  0.2858 sec.
# -------------
# Epoch 287/300
# -------------
# （train）
# -------------
# epoch 287 || Epoch_D_Loss:0.0032 ||Epoch_G_Loss:0.6755
# timer:  0.2770 sec.
# -------------
# Epoch 288/300
# -------------
# （train）
# -------------
# epoch 288 || Epoch_D_Loss:0.0510 ||Epoch_G_Loss:0.5277
# timer:  0.2946 sec.
# -------------
# Epoch 289/300
# -------------
# （train）
# -------------
# epoch 289 || Epoch_D_Loss:0.0170 ||Epoch_G_Loss:0.4574
# timer:  0.2810 sec.
# -------------
# Epoch 290/300
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.0053 ||Epoch_G_Loss:0.6479
# timer:  0.2756 sec.
# -------------
# Epoch 291/300
# -------------
# （train）
# -------------
# epoch 291 || Epoch_D_Loss:0.0764 ||Epoch_G_Loss:0.4101
# timer:  0.2779 sec.
# -------------
# Epoch 292/300
# -------------
# （train）
# -------------
# epoch 292 || Epoch_D_Loss:0.0047 ||Epoch_G_Loss:0.6203
# timer:  0.2764 sec.
# -------------
# Epoch 293/300
# -------------
# （train）
# -------------
# epoch 293 || Epoch_D_Loss:0.0366 ||Epoch_G_Loss:0.6204
# timer:  0.2787 sec.
# -------------
# Epoch 294/300
# -------------
# （train）
# -------------
# epoch 294 || Epoch_D_Loss:0.0302 ||Epoch_G_Loss:0.4186
# timer:  0.2892 sec.
# -------------
# Epoch 295/300
# -------------
# （train）
# -------------
# epoch 295 || Epoch_D_Loss:0.0060 ||Epoch_G_Loss:0.5865
# timer:  0.2770 sec.
# -------------
# Epoch 296/300
# -------------
# （train）
# -------------
# epoch 296 || Epoch_D_Loss:0.0072 ||Epoch_G_Loss:0.7008
# timer:  0.2770 sec.
# -------------
# Epoch 297/300
# -------------
# （train）
# -------------
# epoch 297 || Epoch_D_Loss:0.0549 ||Epoch_G_Loss:0.5109
# timer:  0.2754 sec.
# -------------
# Epoch 298/300
# -------------
# （train）
# -------------
# epoch 298 || Epoch_D_Loss:0.0068 ||Epoch_G_Loss:0.5491
# timer:  0.2765 sec.
# -------------
# Epoch 299/300
# -------------
# （train）
# -------------
# epoch 299 || Epoch_D_Loss:0.0027 ||Epoch_G_Loss:0.6906
# timer:  0.2761 sec.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)
fake_images = G_update(fixed_z.to(device))

batch_iterator = iter(train_dataloader)  
imges = next(batch_iterator)


fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# # AnoGANの

# %%
def Anomaly_score(x, fake_img, D, Lambda=0.1):

    residual_loss = torch.abs(x-fake_img)
    residual_loss = residual_loss.view(residual_loss.size()[0], -1)
    residual_loss = torch.sum(residual_loss, dim=1)

    _, x_feature = D(x)
    _, G_feature = D(fake_img)

    discrimination_loss = torch.abs(x_feature-G_feature)
    
    # discrimination_loss = discrimination_loss.view(
    #    discrimination_loss.size()[0], -1)
    
    discrimination_loss = torch.sum(discrimination_loss, dim=1)

    loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_loss

    total_loss = torch.sum(loss_each)

    return total_loss, loss_each, residual_loss

# %%
def make_test_datapath_list():

    train_img_list = list() 

    for img_idx in range(5):
        img_path = "./data/test/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test/img_2_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


test_img_list = make_test_datapath_list()

# Dataset
mean = (0.5,)
std = (0.5,)
test_dataset = GAN_Img_Dataset(
    file_list=test_img_list, transform=ImageTransform(mean, std))

# DataLoader
batch_size = 5

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)

# %%
batch_iterator = iter(test_dataloader)
imges = next(batch_iterator)  

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

# %%
x = imges[0:5]
x = x.to(device)

z = torch.randn(5, 20).to(device)
z = z.view(z.size(0), z.size(1), 1, 1)

z.requires_grad = True

z_optimizer = torch.optim.Adam([z], lr=1e-3)


for epoch in range(5000+1):
    fake_img = G_update(z)
    loss, _, _ = Anomaly_score(x, fake_img, D_update, Lambda=0.1)

    z_optimizer.zero_grad()
    loss.backward()
    z_optimizer.step()

    if epoch % 1000 == 0:
        print('epoch {} || loss_total:{:.0f} '.format(epoch, loss.item()))
# Out:
# epoch 0 || loss_total:7385
# epoch 1000 || loss_total:5278
# epoch 2000 || loss_total:4377
# epoch 3000 || loss_total:3462
# epoch 4000 || loss_total:3031
# epoch 5000 || loss_total:2547

# %%
G_update.eval()
fake_img = G_update(z)

loss, loss_each, residual_loss_each = Anomaly_score(
    x, fake_img, D_update, Lambda=0.1)

loss_each = loss_each.cpu().detach().numpy()
print("total loss：", np.round(loss_each, 0))

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_img[i][0].cpu().detach().numpy(), 'gray')
# Out:
# total loss： [431. 404. 804. 521. 389.]
